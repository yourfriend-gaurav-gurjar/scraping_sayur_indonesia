# %%
# Loading the libraries
library(tidyverse)
library(httr)
library(jsonlite)
library(lubridate)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# v ggplot2 3.1.1       v purrr   0.3.2
# v tibble  2.1.1       v dplyr   0.8.0.1
# v tidyr   0.8.3       v stringr 1.4.0
# v readr   1.3.1       v forcats 0.4.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
#
# Attaching package: 'jsonlite'
#
# The following object is masked from 'package:purrr':
#
#     flatten
#
#
# Attaching package: 'lubridate'
#
# The following object is masked from 'package:base':
#
#     date

# %%
url <- "https://api.pasarnow.com/api/appProductListNotLoggedIn?page=0&category=CAT-20-06-0000004&subcategory=" # the data from the first API URL 
json <- fromJSON(url) # Scraping the json from the URL
json$pages -> total_pages   # Total number of pages of Sayur products
json$total -> total_products  # Total number of products 
pages <- ceiling(total_products/total_pages) # Per page product listing

# %%
# Loop to scrape all the products in every page
for (pages in (0:pages)) {
  print(paste0("Getting data from page:", pages)) # Printing the message of all the pages step by step
  pages_url <- paste0("https://api.pasarnow.com/api/appProductListNotLoggedIn?page=", pages, "&category=CAT-20-06-0000004&subcategory=") # Scraping the data from all the URLs of API
  tmp_json <- fromJSON(pages_url)  # Extracting the JSON format from the every page
  tmp_json$products[["description"]] -> description  # Extracting description of the products
  tmp_json$products[["product_name"]] -> product_name # Extracting product names 
  tmp_json$products[["original_price"]] -> original_price # Extracting original prices of products
  tmp_json$products[["resale_price"]] -> resale_price # Extracting the resale prices of products
  data.frame(product_name, description, original_price, resale_price) -> tmp_df # Saving them in dataframe
  
  # Loop to save all the dataframe from the pages
  if(pages == 0){
    sayur_pasarnow <- data.frame(product_name, description, original_price, resale_price) # the first scraping dataframe
  } else {
    sayur_pasarnow <- rbind(sayur_pasarnow, tmp_df)  # Binding the every new dataframes to the existing ones
  }
}
# Out:
# [1] "Getting data from page:0"
# [1] "Getting data from page:1"
# [1] "Getting data from page:2"
# [1] "Getting data from page:3"
# [1] "Getting data from page:4"
# [1] "Getting data from page:5"
# [1] "Getting data from page:6"
# [1] "Getting data from page:7"
# [1] "Getting data from page:8"
# [1] "Getting data from page:9"
# [1] "Getting data from page:10"

# %%
scrape_date <- now() # Current Date
date_stamp <- scrape_date %>% format("%y%m%d") # Formatting the date in YYYY-MM-DD format

# %%
write_csv(sayur_pasarnow, path = paste0("scrape_sayur_pasarnow_", date_stamp, ".csv")) # Writing the dataframe into CSV file format

# %%
read_csv('scrape_sayur_pasarnow_200820.csv')
# Out:
# Parsed with column specification:
# cols(
#   product_name = col_character(),
#   description = col_character(),
#   original_price = col_double(),
#   resale_price = col_double()
# )
#     product_name
# 1   Cabe Merah Keriting 1kg
# 2   Timun Lalap 1kg
# 3   Cabe Rawit Merah 1kg
# 4   Tomat Reguler 500gr
# 5   Oyong 1kg
# 6   Paprika Hijau 1 Pack 3pcs
# 7   Cabe Merah Keriting 250gr
# 8   Bawang Putih Bonggol 500gr
# 9   Kacang Panjang 500gr
# 10  Bawang Putih Kating 500gr
# 11  Sawi Putih 500gr - 800gr - 1 Pcs
# 12  Cabe Rawit Merah 250gr
# 13  Labu Siam 800gr - 1000gr
# 14  Jamur Tiram 500gr
# 15  Jagung manis Kulit 3Pcs
# 16  Jeruk Nipis 250gr
# 17  Paprika Kuning 1 Pack 3pcs
# 18  Kentang Super 1kg
# 19  Daun Singkong 500gr
# 20  Daun Bawang 500gr
# 21  Kailan 1Pack 500gr
# 30  Cabe Hijau Keriting 250gr Harga dapat berubah sewaktu-waktu
# ... ...
# 66  Labu Siam Acar500gr ukuran kecil Harga dapat berubah sewaktu-waktu
# 67  Lengkoas 500gr Harga dapat berubah sewaktu-waktu
# 68  Lengkoas 250gr Harga dapat berubah sewaktu-waktu
# 69  Nangka Muda 500gr Harga dapat berubah sewaktu-waktu
# 70  Pare 1kg Harga dapate berubah sewaktu-waktu
# 71  Sawi Hijau 500gr Harga dapat berubah sewaktu-waktu
# 72  Seledri 500gr Harga dapat berubah sewaktu-waktu
# 73  Timun Acar 500gr Harga dapat beubah sewaktu-waktu
# 74  Tomat Hijau 500gr Harga dapat berubah sewaktu-waktu
# 75  Kunyit 250gr harga dapat berubah sewaktu-waktu
# 76  Paprika Merah 1 Pack - 3pcs Harga dapat berubah sewaktu-waktu
# 77  Kacang Tanah Kupas 1kg Harga dapat berubah sewaktu-waktu
# 78  Kacang Hijau 1kg Harga dapat berubah sewaktu-waktu
# 79  Ubi Merah 1kg Harga dapat berubah sewaktu-waktu
# 80  Ubi Putih 1kg Harga dapat berubah sewaktu-waktu
# 81  Selada Keriting 1Pack - 400gr-500gr. Harga dapat berubah sewaktu-waktu
# 82  Lobak 1kg Harga dapat berubah sewaktu-waktu
# 83  Daun Jeruk 250gr Harga dapat berubah sewaktu-waktu
# 84  Bawang Merah Kupas 250gr\nHarga dapat berubah sewaktu-waktu
# 85  Bawang Putih Kupas 250gr\nHarga dapat berubah sewaktu-waktu
# 86  Bayam 250gr\nHarga dapat berubah sewaktu-waktu
# 87  Daun Salam 250gr\nHarga dapat berubah sewaktu-waktu
# 88  Daun Bawang 250gr\nHarga dapat berubah sewaktu-waktu
# 89  Daun Pandan 250gr\nHarga dapat berubah sewaktu-waktu
# 90  Sereh 250gr\nHarga dapat berubah sewaktu-waktu
# 91  Bawang Merah Reguler 250gr\nHarga dapat berubah sewaktu-waktu
# 92  Bawang Putih Kating 250gr\nHarga dapat berubah sewaktu-waktu
# 93  Kacang Tanah Kupas 500gr\nHarga dapat berubah sewaktu-waktu
# 94  Seledri 250gr\nHarga dapat berubah sewaktu-waktu
# 95  Jahe Gajah 500gr\nHarga dapat berubah sewaktu-waktu
#     original_price resale_price
# 1   26800          22000
# 2   14800           8900
# 3   35000          22400
# 4   10900           7500
# 5   17000          14000
# 6   27700          19900
# 7    7500           5700
# 8   16000          11800
# 9   13000          10200
# 10  18900          15700
# 11  15900           9900
# 12   8800           5800
# 13  16500          11800
# 14  17000          13900
# 15  18500          11900
# 16   7700           4200
# 17  34900          28900
# 18  19500          16000
# 19   9900           6200
# 20  12000           8800
# 21  16200           9000
# 22  12000           7900
# 23  10300           7900
# 24  11000           8000
# 25  24200          15900
# 26   9000           6500
# 27  15900          13400
# 28  20700          16800
# 29  13900           9200
# 30  15700           5500
# ... ...            ...
# 66  10500           7000
# 67  14100           9700
# 68   6800           4900
# 69  10900           7000
# 70  16000          12900
# 71  11300           7900
# 72  18000          12900
# 73   8800           6000
# 74  10000           6000
# 75   7500           4200
# 76  34900          25700
# 77  55900          43200
# 78  40200          31900
# 79  15000          11800
# 80  15000          10900
# 81  15700          11400
# 82  15200          12500
# 83  11900           9800
# 84  16000           9800
# 85  12500           8200
# 86   6500           4200
# 87   5000           3500
# 88   6300           4500
# 89   8000           5800
# 90   6500           4000
# 91  14500           8200
# 92  11500           7700
# 93  25600          21800
# 94   9900           6500
# 95  24700          20500
